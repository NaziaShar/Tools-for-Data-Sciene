# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Peer-graded Assignment: Submit Your Work and Grade Your Peers

# %% [markdown]
# ## Introduction of Findal graded assignment

# %% [markdown]
# ### Data Science Languages
#
# - **Python**
# - **R**
# - **Julia**
# - **SQL**
# - **Scala**
# - **Java**

# %% [markdown]
# ### Data Science Libraries
#
# ### *Python*
#
# - **Pandas**
# - **NumPy**
# - **Matplotlib**
# - **Seaborn**
# - **Scikit-learn**
#
# ### *R*
#
# - **ggplot2**
# - **dplyr**
# - **caret**

# %% [markdown]
# ### Data Science Tools
#
# - **Jupyter Notebook**
# - **RStudio**
# - **Git/GitHub**
# - **Tableau**
# - **Excel**
# - **Apache Spark**
# - **Google Colab**
# - **Anaconda Navigator**

# %% [markdown]
# ### **Arithmetic expression examples**

# %%
a = 5
b = 10
product = a * b
print("Product:", product)


x = 7
y = 3
sum_result = x + y
print("Sum:", sum_result)
# Out:
# Product: 50
# Sum: 10

# %% [markdown]
# ### **Convert minutes to hours**

# %%
minutes = 150
hours = minutes / 60
print(minutes, "minutes is equal to", hours, "hours")
# Out:
# 150 minutes is equal to 2.5 hours

# %% [markdown]
# ### Objectives
#
# - **Understand the basics of Data Science and its applications**
# - **Learn about key Data Science languages and libraries**
# - **Familiarize with Data Science tools and their uses**
# - **Perform simple arithmetic operations using Python**
# - **Learn to convert units (e.g., minutes to hours) in Python**
# - **Create a well-structured JupyterLite Notebook with Markdown and Code cells**

# %% [markdown]
# ### Author
#
# **Nazia Shar**
